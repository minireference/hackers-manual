# %%
import re

# %%
source = open('allsource.txt').read()

# %%
len(source.split('\n'))
# Out:
# 4987

# %%
def find_url_in_line(line):
    """
    Return stripped URL if `line` contains a URL, else returns None.
    """
    url_re = re.compile(r'^(?P<url>https?://.*?)$')
    match = url_re.match(line)
    if match:
        raw_url = match.groupdict()['url']
        url = raw_url.rstrip('\ \t')
        return url
    else:
        return None


def is_url(line):
    if line is None:
        return False
    elif find_url_in_line(line) is None:
        return False
    else:
        return True


def is_blank(line):
    if line is None:
        return True
    if len(line.strip()) == 0:
        return True
    else:
        return False

def strip_title_line(line):
    return line.lstrip('[ ').rstrip('\ ]')


def scripted_title(filename):
    """
    Returns the automatically-inserted H5 title e.g. 
    some_topic 
    -->
    ===== Some topic =====
    """
    title = filename.replace("_"," ").capitalize()
    return "===== " + title + " ====="

# %%
STATE_TEXT = 's:text'
STATE_LINK = 's:link'
STATE_EXTRA = 's:extra'
 
def process_source(source, filename):
    """
    Splits off links (title, url, notes) from source, and return rest.
    Level 5 wiki headings containing `filename` will also be skippled.
    """
    # setup results
    links_data = []
    rest_of_source = []
    
    state = STATE_TEXT
    lines = source.splitlines()
    for n, line in enumerate(lines):
        thisline = line
        if n < len(lines)-1:
            nextline = lines[n+1]
        else:
            nextline = None        
        
        #
        # text state
        if state == STATE_TEXT:
            if is_url(nextline):
                state = STATE_LINK
                link = {}
                link['title'] = strip_title_line(thisline)
            else:
                if line.lower() == scripted_title(filename).lower() or is_blank(thisline):
                    pass # skip auto-scripted titles, and blank lines
                else:
                    rest_of_source.append(thisline)
        #
        # link
        elif state == STATE_LINK:
            link['url'] = find_url_in_line(thisline)
            if is_blank(nextline):
                links_data.append(link)
                state = STATE_TEXT
                link = None
            else:
                state = STATE_EXTRA        
        #
        # extra text after link
        elif state == STATE_EXTRA:
            thisline = thisline.rstrip('\ ')
            link['extra'] = link.get('extra', '') + thisline
            if is_blank(nextline):
                state = STATE_TEXT
                links_data.append(link)
                link = None
            else:
                link['extra'] += '\n'
        #
        else:
            raise ValueError('Should never be here')

    return links_data, rest_of_source

# %%
links_data, rest_of_source = process_source(source, 'javascript_backbone')
# Out:
# http://www.comp.nus.edu.sg/~stevenha/visualization/index.html
# http://stackoverflow.com/questions/487258/plain-english-explanation-of-big-o
# http://www.algorist.com/
# https://www.siam.org/pdf/news/637.pdf
# http://cstheory.stackexchange.com/questions/19759/core-algorithms-deployed/19773#19773
# http://en.docsity.com/news/interesting-facts/great-algorithms-revolutionized-computing/
# https://github.com/nzakas/computer-science-in-javascript/
# http://bigocheatsheet.com/
# http://www.caseyrule.com/projects/sounds-of-sorting/
# https://queue.acm.org/detail.cfm?id=2855183
# http://www3.cs.stonybrook.edu/~algorith/video-lectures/
# https://news.ycombinator.com/item?id=11712198
# http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-046j-design-and-analysis-of-algorithms-spring-2015/lecture-videos/
# http://algo-visualizer.jasonpark.me/
# http://www.ilikebigbits.com/blog/2014/4/21/the-myth-of-ram-part-i
# https://rosettacode.org/wiki/Sorting_algorithms/Quicksort#Python
# https://news.ycombinator.com/item?id=13517597
# https://www.objc.io/issues/11-android/android_101_for_ios_developers/
# https://github.com/android10/Android-CleanArchitecture
# https://cloudrail.com/best-android-libraries-for-developers/
# https://blog.torproject.org/blog/mission-improbable-hardening-android-security-and-privacy
# https://garbagecollected.org/2017/01/31/four-column-ascii/
# http://www.jyotirmoy.net/posts/2015-04-22-assembly-hello-world.html
# https://www.nayuki.io/page/a-fundamental-introduction-to-x86-assembly-programming
# http://patshaughnessy.net/2016/11/26/learning-to-read-x86-assembly-language
# http://atastypixel.com/blog/four-common-mistakes-in-audio-development/
# http://blog.bignerdranch.com/3799-a-crash-course-in-awk/
# http://ferd.ca/awk-in-20-minutes.html
# https://www.airpair.com/aws/posts/building-a-scalable-web-app-on-amazon-web-services-p1?wed
# http://highscalability.com/blog/2016/1/11/a-beginners-guide-to-scaling-to-11-million-users-on-amazons.html
# https://cloudcraft.co/
# https://quizlet.com/blog/whats-the-best-cloud-probably-gcp
# https://segment.com/blog/the-segment-aws-stack/
# http://aws-api.info/s3/2006-03-01
# https://gist.github.com/leonardofed/bbf6459ad154ad5215d354f3825435dc
# https://aws.amazon.com/start-now/
# https://autozane.com/automating-aws-cloudwatch-logs-on-ubuntu/
# https://github.com/open-guides/og-aws
# http://www.ec2instances.info/
# https://rbgeek.wordpress.com/2016/05/15/autoscaling-with-aws-instances-using-ansible-pull/
# http://start.jcolemorrison.com/aws-iam-policies-in-a-nutshell/
# https://news.ycombinator.com/item?id=12999767
# http://www.oliverelliott.org/article/computing/tut_unix/
# http://www.joshstaiger.org/archives/2005/07/bash_profile_vs.html
# http://redsymbol.net/articles/unofficial-bash-strict-mode/
# http://bytemuse.com/post/the-terminal-crash-course-and-reference-sheet/
# http://www.fizerkhan.com/blog/posts/What-I-learned-from-other-s-shell-scripts.html
# http://www.davidpashley.com/articles/writing-robust-shell-scripts/
# http://www.shellcheck.net/#
# http://google-styleguide.googlecode.com/svn/trunk/shell.xml#Indentation
# https://google.github.io/styleguide/shell.xml
# https://news.ycombinator.com/item?id=2415365
# http://www.pixelbeat.org/programming/shell_script_mistakes.html
# http://www.danielmiessler.com/blog/collection-of-less-commonly-used-unix-commands
# http://www.webdesignporto.com/get-started-with-unix-command-line-vim-and-sh-for-the-total-windows-newbie/
# http://www.kfirlavi.com/blog/2012/11/14/defensive-bash-programming/
# http://m.odul.us/blog/2015/8/12/stronger-shell
# http://mywiki.wooledge.org/BashPitfalls
# http://www.learnenough.com/command-line
# http://www.etalabs.net/sh_tricks.html
# https://github.com/mrzool/bash-sensible
# http://redsymbol.net/articles/unofficial-bash-strict-mode/
# http://samrowe.com/wordpress/advancing-in-the-bash-shell/
# https://sanctum.geek.nz/arabesque/series/unix-as-ide/
# http://www.catonmat.net/download/bash-history-cheat-sheet.pdf
# https://github.com/myplaceonline/posixcube
# https://github.com/jlevy/the-art-of-command-line
# https://www.blockloop.io/mastering-bash-and-terminal
# http://samrowe.com/wordpress/advancing-in-the-bash-shell/
# https://cmdchallenge.com/
# http://jvns.ca/blog/2017/03/26/bash-quirks/
# http://stackoverflow.com/questions/2307283/what-does-olog-n-mean-exactly/2307314#2307314
# http://bigocheatsheet.com/
# http://bitcoin.stackexchange.com/questions/19950/how-are-public-and-private-keys-related-to-the-wallet
# http://www.alexkyte.me/2016/08/consensus-without-trust-cryptographic.html
# https://media.blackhat.com/us-13/us-13-Ryan-Bluetooth-Smart-The-Good-The-Bad-The-Ugly-and-The-Fix.pdf
# http://blog.bluetooth.com/everything-you-always-wanted-to-know-about-bluetooth-security-in-bluetooth-4-2/
# https://pomcor.com/2015/06/03/has-bluetooth-become-secure/
# http://bluetooth-pentest.narod.ru/
# https://www.google.com/#q=bluetooth+protocol+.pdf
# http://www.nirsoft.net/utils/bluetooth_viewer.html
# https://play.google.com/store/apps/details?id=com.silentservices.btCrawler&hl=en
# https://sourceforge.net/projects/btcrawler/
# https://github.com/greatscottgadgets/ubertooth/
# https://github.com/greatscottgadgets/ubertooth/wiki
# https://github.com/vhf/free-programming-books/blob/master/free-programming-books.md
# https://openlibra.com/en/collection/search/language/english/
# https://www.ossblog.org/books/
# http://hackershelf.com/browse/
# http://www.eskimo.com/~scs/cclass/int/top.html
# http://alumni.cs.ucr.edu/~pdiloren/C++_Pointers/
# http://c-faq.com/decl/spiral.anderson.html
# http://c.learncodethehardway.org/book/ex20.html
# https://matt.sh/howto-c
# http://www.bell-labs.com/usr/dmr/www/chist.html
# http://www.toves.org/books/cpy/
# http://www.gowrikumar.com/c/index.php
# https://brennan.io/2015/01/16/write-a-shell-in-c/
# https://www.mnot.net/cache_docs/
# http://star.mit.edu/cluster/
# http://kevinlondon.com/2015/05/05/code-review-best-practices.html
# http://www.modrails.com/documentation/Users%20guide%20Apache.html#about_environment_variables
# https://github.com/jlevy/the-art-of-command-line
# http://www.pixelstech.net/article/index.php?id=1352219881
# http://sysadmincasts.com/episodes/13-crash-course-on-common-commands
# http://learnpythonthehardway.org/book/appendixa.html
# http://viget.com/extend/level-up-your-shell-game
# http://matt.might.net/articles/settling-into-unix/
# http://kkovacs.eu/cool-but-obscure-unix-tools/
# http://pindexis.github.io/command-line/2015/12/23/power-of-commmand-line.html
# http://www.learnenough.com/command-line-tutorial
# http://nathansuniversity.com/
# https://medium.com/@kosamari/how-to-be-a-compiler-make-a-compiler-with-javascript-4a8a13d473b4
# https://tomassetti.me/antlr-mega-tutorial/
# http://fabiensanglard.net/Computer_Graphics_Principles_and_Practices/index.php
# https://github.com/prakhar1989/awesome-courses/blob/master/README.md
# http://www.cs.hmc.edu/csforall/
# https://medium.com/@spiffy_spaceman/teach-yourself-computer-science-374d2fd5624e
# https://github.com/Developer-Y/cs-video-courses
# https://www.google.com/edu/cs/index.html
# https://keon.io/cs/computer-scientists-trivia/
# http://www.careercup.com/page
# http://www.laputan.org/mud/
# https://thetechladder.com/story/removing-dread-internal-enterprise-systems/
# http://blog.siftscience.com/why-are-payment-forms-so-complicated-2/
# https://msdn.microsoft.com/en-us/library/ms978509.aspx
# https://news.ycombinator.com/item?id=10626445
# https://paragonie.com/blog/2015/08/you-wouldnt-base64-a-password-cryptography-decoded
# http://blog.cryptographyengineering.com/p/useful-cryptography-resources.html
# http://loup-vaillant.fr/articles/rolling-your-own-crypto
# http://howtocenterincss.com/
# http://codepen.io/shshaw/full/gEiDt
# http://shoelace.io/
# http://hackerthemes.com/bootstrap-cheatsheet#dropdown
# https://css-tricks.com/snippets/css/a-guide-to-flexbox/
# http://flexboxfroggy.com/
# http://www.flexboxdefense.com/
# https://philipwalton.github.io/solved-by-flexbox/
# http://www.flexboxpatterns.com/home
# https://scotch.io/tutorials/a-visual-guide-to-css3-flexbox-properties
# http://yoksel.github.io/flex-cheatsheet/
# https://raygun.io/blog/2014/06/next-gen-constraint-layouts-browser-grid-style-sheets/
# http://www.designer-daily.com/10-useful-css-generation-tools-for-web-designers-52509
# https://csspeeper.com/
# http://reports.quickleft.com/css
# http://sarasoueidan.com/blog/css-shapes/index.html
# http://blog.froont.com/positioning-in-web-design/
# http://supermarkupworld.daggasoft.com/
# http://madebymike.com.au/writing/precise-control-responsive-typography/
# http://www.codingdefined.com/2016/01/html5-responsive-frameworks-for-web.html
# https://gist.github.com/jareware/4738651
# http://flukeout.github.io/
# http://pumpula.net/p/apps/css-vocabulary/
# http://css-tricks.com/child-and-sibling-selectors/
# https://github.com/rstacruz/rscss
# https://github.com/AllThingsSmitty/css-protips
# http://zellwk.com/blog/why-vertical-rhythms/
# https://news.ycombinator.com/item?id=11213213
# https://github.com/sympy/sympy/wiki/SymPy-vs.-Sage
# http://saedsayad.com/
# http://christonard.com/12-free-data-mining-books/
# http://datasciencemasters.org/
# http://insightdataengineering.com/blog/pipeline_map.html
# http://www.unofficialgoogledatascience.com/2016/10/practical-advice-for-analysis-of-large.html
# http://www.mmds.org/
# http://www.martingoodson.com/ten-ways-your-data-project-is-going-to-fail/
# https://github.com/acastrounis/data-science-resources
# https://hackernoon.com/wannabe-data-scientists-learn-the-basics-with-these-7-books-1a41cfbbdd34
# https://jeffersonheard.github.io/2017/01/being-a-data-scientist-my-experience-and-toolset/
# https://github.com/donnemartin/data-science-ipython-notebooks
# http://cstheory.stackexchange.com/a/1550/7273
# http://www.grokit.ca/spc/computer_science_review/
# http://www.cs.usfca.edu/~galles/visualization/Algorithms.html
# https://github.com/thejameskyle/itsy-bitsy-data-structures
# http://courses.csail.mit.edu/6.851/
# https://www.techiedelight.com/best-online-courses-data-structures-algorithms/
# http://www.datavizcatalogue.com/
# http://blog.lostpropertyhq.com/postgres-full-text-search-is-good-enough/
# http://coding-geek.com/how-databases-work/
# https://wiki.postgresql.org/wiki/Replication,_Clustering,_and_Connection_Pooling
# http://www.databaseanswers.org/data_models/
# https://github.com/dhamaniasad/awesome-postgres
# https://github.com/dbcli/mycli
# http://plusbryan.com/my-first-5-minutes-on-a-server-or-essential-security-for-linux-servers
# https://github.com/ansistrano/deploy
# https://github.com/donnemartin/system-design-primer
# http://ifeanyi.co/posts/understanding-consensus/
# https://medium.com/baqend-blog/nosql-databases-a-survey-and-decision-guidance-ea7823a822d
# https://github.com/pydanny/cookiecutter-django
# https://www.youtube.com/watch?v=C0wuTkS93B0
# https://www.webforefront.com/django/setupdjangologging.html
# https://news.ycombinator.com/item?id=13024003
# http://awesome-django.com/
# https://developer.mozilla.org/en-US/docs/Learn/Server-side/Django
# http://10kblogger.wordpress.com/2012/05/25/a-restful-password-locker-with-django-and-backbone-js/
# https://www.openshift.com/blogs/day-21-docker-the-missing-tutorial
# http://containerops.org/2013/11/19/lxc-networking/
# https://gist.github.com/wsargent/7049221
# https://blog.containership.io/containers-vs-config-management-e64cbb744a94
# https://www.elastic.co/guide/en/elasticsearch/guide/current/index.html
# http://www.manning.com/hinman/
# https://tech.scrunch.com/blog/lessons-learned-from-a-year-of-running-elasticsearch-in-production/
# http://www.havingatinker.uk/aws-elasticsearch-service-woes.html
# https://ldpreload.com/blog/names-to-reserve
# https://www.youtube.com/watch?v=0nbkaYsR94c
# http://serverfault.com/questions/127795/tar-a-directory-and-only-include-certain-file-types
# http://blog.reverberate.org/2014/09/what-every-computer-programmer-should.html
# http://www.over-yonder.net/~fullermd/rants/bsd4linux/01
# https://www.youtube.com/watch?v=E8I19uA-wGY
# https://github.com/hemanth/functional-programming-jargon
# https://maryrosecook.com/blog/post/a-practical-introduction-to-functional-programming
# http://feederio.com/book/36/beautiful-javascript-functional-javascript
# https://news.ycombinator.com/item?id=13612587
# https://medium.com/@abhasvc/unicorns-vs-donkeys-your-handy-guide-to-distinguishing-who-s-who-f1b30942b2b6#.b9vqy9cw2
# http://evjang.com/articles/computer_tips
# http://luisbg.blogalia.com//historias/76017
# https://www.atlassian.com/git/
# https://github.com/blog/2019-how-to-undo-almost-anything-with-git
# http://www.ndpsoftware.com/git-cheatsheet.html#loc=workspace;
# http://eev.ee/blog/2015/04/24/just-enough-git-to-be-less-dangerous/
# http://www.alexkras.com/19-git-tips-for-everyday-use/
# https://help.github.com/articles/syncing-a-fork
# https://www.andyjeffries.co.uk/25-tips-for-intermediate-git-users/
# https://blog.codeminer42.com/git-workflow-basics-d405746f6205
# https://medium.com/@pierreda/understanding-git-for-real-by-exploring-the-git-directory-1e079c15b807#.zgnotn4fd
# https://www.atlassian.com/git/tutorials/comparing-workflows/forking-workflow
# https://github.com/pstadler/keybase-gpg-github
# https://git.wiki.kernel.org/index.php/GitTips
# http://git-memo.readthedocs.io/en/latest/introduction.html
# http://ohshitgit.com/
# https://www.alexkras.com/19-git-tips-for-everyday-use/
# https://codewords.recurse.com/issues/two/git-from-the-inside-out
# http://learngitbranching.js.org/
# https://www.youtube.com/watch?v=3m7BgIvC-uQ
# https://try.github.io/levels/1/challenges/1
# https://training.github.com/kit/courses/github-for-developers.html
# https://help.github.com/articles/syncing-a-fork/
# https://www.digitalocean.com/community/tutorials/how-to-use-gpg-to-encrypt-and-sign-messages-on-an-ubuntu-12-04-vps
# https://help.riseup.net/en/security/message-security/openpgp/best-practices
# https://begriffs.com/posts/2016-11-05-advanced-intro-gnupg.html
# http://www.sitepoint.com/linux-design-tools/
# http://www.forentrepreneurs.com/saas-metrics-2/#Calculating_CAC_and_LTV
# https://github.com/knsv/mermaid
# http://www.tkdocs.com/
# https://github.com/carpedm20/awesome-hacking
# http://insightdataengineering.com/blog/hadoopdevops/
# https://blog.insightdatascience.com/spinning-up-a-free-hadoop-cluster-step-by-step-c406d56bae42
# https://ymichael.com/2015/06/06/some-notes-playing-with-haproxy.html
# https://hughewilliams.com/2012/10/01/five-myths-about-hash-tables/
# http://chrisuehlinger.com/LambdaBubblePop/
# http://www.haskellforall.com/2014/07/equational-reasoning-at-scale.html
# http://www.seas.upenn.edu/~cis194/spring13/
# https://en.wikibooks.org/wiki/Write_Yourself_a_Scheme_in_48_Hours
# http://book.realworldhaskell.org/read/
# http://andrew.gibiansky.com/blog/haskell/haskell-syntax/
# http://tldp.org/LDP/abs/html/here-docs.html
# https://en.wikipedia.org/wiki/Here_document
# http://w3c.github.io/elements-of-html/
# http://www.html-5-tutorial.com/footer-element.htm
# https://hacks.mozilla.org/2016/08/a-few-html-tips/
# https://github.com/mjhea0/thinkful-html
# http://www.allanberger.com/post/49938151321/how-to-make-your-apps-retina-ready
# http://cssarrowplease.com/
# http://kev.inburke.com/kevin/helping-you-get-html-right/
# http://learn.shayhowe.com/advanced-html-css/performance-organization
# http://mathiasbynens.be/notes/html5-levels
# http://learn.shayhowe.com/advanced-html-css/responsive-web-design
# http://cssreference.io/
# http://www.cssreflex.com/css-frameworks/
# https://github.com/jakubroztocil/httpie
# https://gist.github.com/willurd/5720255
# https://github.com/mitmproxy/mitmproxy
# https://www.tbray.org/ongoing/When/201x/2012/12/02/HTTPS
# http://www.moserware.com/2009/06/first-few-milliseconds-of-https.html
# https://certsimple.com/blog/obsolete-cipher-suite-and-things-web-developers-should-know-about-ssl
# https://wiki.mozilla.org/Security/Server_Side_TLS
# http://www.bloomberg.com/graphics/2015-paul-ford-what-is-code/
# http://blog.triplebyte.com/how-to-pass-a-programming-interview
# https://oj.leetcode.com/problems/
# https://github.com/jwasham/google-interview-university
# http://www.geeksforgeeks.org/top-10-algorithms-in-interview-questions/
# http://www.techiedelight.com/graphs-interview-questions/
# http://www.primaryobjects.com/2017/03/28/preparing-for-a-technical-interview-algorithms-data-structures-and-computer-science/
# http://ycombinator.com/arc/tut.txt
# http://www.ittybittycomputers.com/IttyBitty/ShortCor.htm
# https://github.com/alex/what-happens-when
# http://arstechnica.com/science/2012/12/programming-for-all-part-1-an-introduction-to-writing-for-computers/
# http://blog.samstokes.co.uk/blog/2014/05/01/what-programming-is-like/
# http://matt.might.net/articles/what-cs-majors-should-know/
# http://hardmath123.github.io/after-scratch.html
# http://blog.hiphipjorge.com/tips-for-learning-programming/
# https://jvns.ca/blog/so-you-want-to-be-a-wizard/
# http://www.objc.io/issue-6/
# http://strongloop.com/strongblog/apples-ios7-native-javascript-bridge/
# https://github.com/DrBoolean/mostly-adequate-guide
# http://slides.com/concise/js#/
# https://gist.github.com/yig/8744917
# http://jstherightway.org/
# https://news.ycombinator.com/item?id=5434627
# http://superherojs.com/
# https://developer.mozilla.org/en-US/docs/Web/JavaScript/A_re-introduction_to_JavaScript
# http://shichuan.github.com/javascript-patterns/
# http://ianbishop.github.com/blog/2013/01/13/escape-from-callback-hell/
# http://markdaggett.com/blog/2013/02/15/functions-explained/
# http://jaxenter.com/douglas-crockford-java-was-a-colossal-failure-javascript-is-succeeding-because-it-works-45928.html
# http://www.jblotus.com/2013/01/13/common-javascript-gotchas/
# http://blog.bolshchikov.net/post/40917260776/javascript-quiz-set
# http://raganwald.com/2013/03/07/currying-and-partial-application.html
# http://javascript-puzzlers.herokuapp.com/
# https://developer.mozilla.org/en-US/docs/Web/JavaScript/A_re-introduction_to_JavaScript
# http://tutorials.jumpstartlab.com/
# https://developer.mozilla.org/en-US/docs/Web/JavaScript/Data_structures
# http://justinchmura.com/2014/08/20/become-a-better-javascript-developer/
# https://medium.com/javascript-scene/the-two-pillars-of-javascript-ee6f3281e7f3
# http://dorey.github.io/JavaScript-Equality-Table/
# http://bonsaiden.github.io/JavaScript-Garden/
# https://github.com/h5bp/Front-end-Developer-Interview-Questions
# https://github.com/airbnb/javascript
# http://www.collectionsjs.com/
# https://josecasanova.com/blog/21-javascript-answers-on-quora-every-developer-must-read/
# https://segment.com/blog/the-deep-roots-of-js-fatigue/
# http://blog.livecoding.tv/2016/07/12/top-javascript-blogs/
# http://davidwalsh.name/css-js-animation
# http://www.jsgraphs.com/
# https://code.mixpanel.com/2015/04/08/straightening-our-backbone-a-lesson-in-event-driven-ui-development/
# http://weblog.bocoup.com/organizing-your-backbone-js-application-with-modules/
# http://blog.pamelafox.org/2013/07/a-guide-to-writing-backbone-apps-at.html?utm_source=javascriptweekly&utm_medium=email
# https://github.com/jashkenas/backbone/wiki/Tutorials%2C-blog-posts-and-example-sites
# https://github.com/204NoContent/backbone-phonecat
# http://jsbooks.revolunet.com/
# http://eloquentjavascript.net/#2nd-ed
# http://exploringjs.com/
# http://exploringjs.com/es6/index.html
# http://callbackhell.com/
# http://dmitryfrank.com/articles/js_closures
# http://daker.me/2013/12/devtools-console-from-novice-to-ninja.html
# http://techblog.badoo.com/blog/2013/11/18/5-advanced-javascript-and-web-debugging-techniques-you-should-know-about/
# http://bgrins.github.io/devtools-snippets/
# https://news.ycombinator.com/item?id=5415081
# http://discover-devtools.codeschool.com/
# http://quenchjs.com/
# http://tooling.github.io/book-of-modern-frontend-tooling/
# http://www.smashingmagazine.com/2015/09/eslint-the-next-generation-javascript-linter/
# http://mo.github.io/2015/10/19/chrome-devtools.html
# https://medium.com/javascript-scene/must-see-javascript-dev-tools-that-put-other-dev-tools-to-shame-aca6d3e3d925
# http://www.quirksmode.org/js/events_order.html
# https://www.youtube.com/watch?v=8aGhZQkoFbQ
# http://vart.institute/
# http://stats.wikimedia.org/wikimedia/animations/growth/AnimationProjectsGrowthWp.html?canvas_width=1000&canvas_height=750
# http://bjorn.tipling.com/all-this
# http://www.thinkful.com/learn/intro-to-jquery
# https://float-middle.com/json-web-tokens-jwt-vs-sessions/
# http://www.objectplayground.com/
# http://caniuse.com/
# http://html5demos.com
# http://microjs.com/
# http://jsperf.com/
# http://webplatform.org/
# https://developer.mozilla.org/en-US/
# http://componentjs.com/
# http://component.io/
# http://bower.io/
# http://ender.jit.su/
# http://browserify.org/
# http://outbounder.github.io/simpleui-techbrowser/www/index.html#javascript
# http://wiki.commonjs.org/wiki/Modules/1.1
# https://github.com/amdjs/amdjs-api/wiki/AMD
# http://requirejs.org/docs/whyamd.html#amd
# https://github.com/joyent/node/wiki/modules
# https://github.com/defunkt/jquery-pjax
# http://www.ibm.com/developerworks/library/wa-aj-jsonp1/
# http://en.wikipedia.org/wiki/Cross-origin_resource_sharing
# http://jsconsole.com/remote-debugging.html
# http://html.adobe.com/edge/inspect/
# http://www.webrtc.org/
# https://developer.mozilla.org/en-US/docs/Web/HTML/Using_HTML5_audio_and_video
# http://www.slideshare.net/remy.sharp/html5-js-apis
# http://dev.opera.com/articles/view/better-performance-with-requestanimationframe/
# https://developers.google.com/web-toolkit/
# http://asmjs.org/
# http://coffeescript.org/
# https://github.com/clojure/clojurescript
# http://www.infoq.com/presentations/ClojureScript
# http://www.dartlang.org/
# http://www.typescriptlang.org/
# http://haxe.org/
# http://elm-lang.org/Documentation.elm
# http://backbonejs.org/
# http://angularjs.org/
# http://jquerymobile.com/
# http://backplug.io/
# http://www.amplesdk.com/
# http://sproutcore.com/
# http://spinejs.com/
# http://javascriptmvc.com/
# http://www.sencha.com/products/extjs
# http://balderdashy.github.io/sails/
# http://sammyjs.org/
# http://www.sencha.com/products/touch
# http://emberjs.com/
# http://www.kendoui.com/
# http://www.persvr.org/Documentation
# http://lungo.tapquo.com/
# http://enyojs.com/
# http://qooxdoo.org/
# http://thoraxjs.org/
# https://github.com/kolodny/exercises
# https://github.com/FrontendMasters/front-end-handbook-2017
# http://www.adequatelygood.com/JavaScript-Module-Pattern-In-Depth.html
# http://chimera.labs.oreilly.com/books/1230000000545/index.html
# https://github.com/sindresorhus/awesome-nodejs
# http://shichuan.github.io/javascript-patterns/
# http://ferrante.pl/frontend/javascript/objectcreate-history-and-memory-leaks/
# http://pouchdb.com/2015/05/18/we-have-a-problem-with-promises.html
# https://gist.github.com/nolanlawson/6ce81186421d2fa109a4
# http://promise-nuggets.github.io/
# http://www.datchley.name/understanding-prototypes-delegation-composition/
# http://blog.siftscience.com/blog/2015/4/6/d-threeact-how-sift-science-made-d3-react-besties
# http://www.thinkful.com/learn/javascript-best-practices-1/
# https://github.com/bevacqua/js/
# http://berzniz.com/post/68001735765/javascript-hacks-for-hipsters
# https://github.com/Seravo/js-winning-style
# http://qunitjs.com/cookbook/
# http://alistapart.com/article/writing-testable-javascript/
# https://github.com/shekhargulati/52-technologies-in-2016/blob/master/36-webpack/README.md
# https://github.com/rstacruz/webpack-tricks
# https://github.com/simeji/jid
# http://200ok.ch/jq-my-new-favorite-tool-to-work-with-json-on-the-command-line/index.html
# http://danielmartins.ninja/posts/five-months-of-kubernetes.html
# http://containerops.org/2017/01/30/kubernetes-services-and-ingress-under-x-ray/
# https://news.ycombinator.com/item?id=13679705
# https://www.helpscout.net/blog/home-page-design/
# https://github.com/VoLuong/Begin-Latex-in-minutes
# http://texblog.org/2013/11/11/latexs-alternative-letter-class-newlfm/
# http://www.ams.org/publications/authors/tex/tex-pub
# https://www.youtube.com/watch?v=33_yJ2A8kOU
# http://tex.stackexchange.com/questions/42611/list-of-available-tikz-libraries-with-a-short-introduction
# http://www.read.seas.harvard.edu/~kohler/latex.html
# https://en.wikibooks.org/wiki/LaTeX/Print_version
# http://tex.stackexchange.com/questions/40720/latex-in-industry
# http://waterstreetgm.org/throwing-in-the-towel-on-becomming-a-programmer/
# http://blog.fogus.me/2009/05/29/pet-projects/
# https://pragprog.com/book/bhwb/exercises-for-programmers
# http://www.coin-or.org/PuLP/main/the_optimisation_process.html
# https://www.digitalocean.com/community
# https://news.ycombinator.com/item?id=7612783
# http://maxehmookau.github.io/blog/2014/04/28/the-graduate-software-developers-reading-lis/
# http://bitboot.camp/resources.html
# http://www.linfo.org/
# http://monkey.org/~marius/unix-tools-hints.html
# http://jvns.ca/blog/2015/04/06/a-few-spy-tools-for-your-operating-system-other-than-strace/
# http://tobert.github.io/post/2014-06-24-linux-defaults.html
# http://www.linuxprogrammingblog.com/all-about-linux-signals?page=show
# http://www.michaelnielsen.org/ddi/lisp-as-the-maxwells-equations-of-software/
# http://berkeley-cs61as.github.io/
# http://articulate-lisp.com/
# http://hynek.me/articles/taking-some-pain-out-of-python-logging/
# http://blog.parsely.com/post/1691/lucene/
# http://www.autonlab.org/tutorials/list.html
# http://designimag.com/best-free-machine-learning-ebooks/
# https://github.com/josephmisiti/awesome-machine-learning
# http://richardminerich.com/2012/12/my-education-in-machine-learning-via-cousera/
# http://metaoptimize.com/qa/questions/186/good-freely-available-textbooks-on-machine-learning
# http://conductrics.com/data-science-resources/
# http://www.youtube.com/watch?v=R9UoFyqJca8
# http://www.bigdatarepublic.com/author.asp?section_id=2809&doc_id=257527&
# http://www.quora.com/What-are-some-good-resources-for-learning-about-machine-learning-Why
# http://work.caltech.edu/library/
# http://guidetodatamining.com/
# http://www.dmi.usherb.ca/~larocheh/mlpython/tutorial.html#tutorial
# http://info.usherbrooke.ca/hlarochelle/cours/ift725_A2013/contenu.html
# http://homepages.inf.ed.ac.uk/vlavrenk/iaml.html
# http://www.mysliderule.com/learning-paths/data-analysis/learn/
# http://www.quora.com/Machine-Learning/What-are-some-good-resources-for-learning-about-machine-learning
# http://sebastianraschka.com/Articles/2014_naive_bayes_1.html
# https://news.ycombinator.com/item?id=9902524
# http://neuralnetworksanddeeplearning.com/chap6.html
# https://github.com/szilard/benchm-ml
# https://developer.nvidia.com/deep-learning-courses
# https://www.cs.ox.ac.uk/people/nando.defreitas/machinelearning/
# https://github.com/rhiever/Data-Analysis-and-Machine-Learning-Projects/blob/master/example-data-science-notebook/Example%20Machine%20Learning%20Notebook.ipynb
# https://github.com/hangtwenty/dive-into-machine-learning
# http://hunch.net/?p=224
# https://github.com/josephmisiti/awesome-machine-learning
# http://nbviewer.jupyter.org/github/lmcinnes/hdbscan/blob/master/notebooks/Comparing%20Clustering%20Algorithms.ipynb
# http://kennethfriedman.org/projects/escaping-local-min/
# https://news.ycombinator.com/item?id=12559753
# https://simons.berkeley.edu/talks/ben-recht-2013-09-04
# https://news.ycombinator.com/item?id=12713056
# https://elitedatascience.com/learn-machine-learning
# http://www.mitchchn.me/2014/os-x-terminal/
# http://zsmith.co/security.html
# http://ksat.me/map-reduce-a-really-simple-introduction-kloudo/
# http://sebastianraschka.com/Articles/2014_matrix_cheatsheet.html
# http://i308.wikispaces.com/Mathematical+prerequisites
# https://datawire.io/creating-a-microservice-answer-these-10-questions-first/
# https://dzone.com/articles/microservices-please-dont
# http://journal.stuffwithstuff.com/2016/06/16/long-names-are-long/
# http://www.beej.us/guide/bgnet/output/html/singlepage/bgnet.html
# http://news.ycombinator.com/item?id=5256751
# https://github.com/mininet/mininet/wiki/Documentation
# http://tcpipguide.com/free/t_toc.htm
# http://www.objc.io/issue-10/ip-tcp-http.html
# http://m-mizutani.github.io/blog/2014/02/10/dnsviz-en/
# http://jvns.ca/blog/2016/03/16/tcpdump-is-amazing/
# http://bencane.com/2014/10/13/quick-and-practical-reference-for-tcpdump/
# https://www.slac.stanford.edu/xorg/nmtf/nmtf-tools.html
# https://www.nginx.com/resources/wiki/start/topics/tutorials/config_pitfalls/#
# https://www.nginx.com/blog/inside-nginx-how-we-designed-for-performance-scale/
# https://medium.com/@alexmngn/the-essential-boilerplate-to-authenticate-users-on-your-react-native-app-f7a8e0e04a42
# https://www.gluu.org/blog/oauth-vs-saml-vs-openid-connect/
# http://www.benfrederickson.com/numerical-optimization/
# https://www.pentesterlab.com/exercises
# https://wiki.python.org/moin/PerlPhrasebook
# https://github.com/alexeyza/startup-programming/tree/master/resources/tutorials
# http://russ.garrett.co.uk/2015/10/02/postgres-monitoring-cheatsheet/
# https://www.pgcasts.com/
# https://pgexercises.com/
# https://tech.lendinghome.com/practical-guide-to-postgresql-optimizations-d7b9c2ad6a22
# http://rachbelaid.com/postgres-full-text-search-is-good-enough/
# http://thebuild.com/presentations/pgconfeu-2016-securing-postgresql.pdf
# https://github.com/wal-e/wal-e
# http://renesd.blogspot.ca/2017/02/is-postgresql-good-enough.html
# http://probabilistic-programming.org/wiki/Home
# https://github.com/shekhargulati/99-problems
# https://news.ycombinator.com/item?id=11752995
# https://wiki.python.org/moin/ProblemSets/99%20Prolog%20Problems%20Solutions
# https://fredrb.github.io/2016/10/01/Understanding-proc/
# http://joearms.github.io/2014/02/07/why-programming-is-difficult.html
# https://medium.com/@tammybutow/graduating-from-bootcamp-and-interested-in-becoming-a-site-reliability-engineer-b69a38ce858b
# http://blogs.lessthandot.com/index.php/ITProfessionals/EthicsIT/collection-of-puzzles-for-programmers
# http://macgyverdev.blogspot.se/2014/04/become-better-programmer-with.html
# https://open.kattis.com/
# http://spinroot.com/p10/index.html
# https://chodounsky.net/2016/12/23/progressive-web-applications/
# https://news.ycombinator.com/item?id=13964551
# https://www.doc.ic.ac.uk/~rak/papers/newbook.pdf
# http://www.mockplus.com/blog/post/prototyping-tools-from-quick-and-dirty-wireframes-to-functional-prototypes/
# https://sphinxcontrib-napoleon.readthedocs.org/en/latest/
# http://www.siafoo.net/article/57
# http://tjheeta.github.io/2015/04/15/ansible-vs-chef/
# http://vcdxpert.com/?p=105
# https://atplanet.co/blog/ec2-auto-scaling-with-ansible.html
# http://www.snarky.ca/how-the-heck-does-async-await-work-in-python-3-5
# https://github.com/ggozad/behaving
# https://github.com/behave/behave-django
# http://pypix.com/python/advanced-data-structures/
# https://www.ics.uci.edu/~pattis/ICS-33/lectures/complexitypython.txt
# https://github.com/rosarior/django-must-watch
# https://github.com/realpython/discover-flask
# http://maryrosecook.com/blog/post/a-practical-introduction-to-functional-programming
# http://www.fmwconcepts.com/imagemagick/
# https://www.youtube.com/watch?v=OSGv2VnC0go
# http://lurnq.com/lesson/Getting-started-with-Python-Tips-Tools-and-Resources/
# http://badhessian.org/2013/11/cluster-computing-for-027hr-using-amazon-ec2-and-ipython-notebook/
# http://pypix.com/scientific/ipython-beginners-guide/
# http://strata.oreilly.com/2013/03/python-data-tools-just-keep-getting-better.html
# https://github.com/mGalarnyk/Python_Tutorials
# http://www.labri.fr/perso/nrougier/from-python-to-numpy/
# http://www.labri.fr/perso/nrougier/from-python-to-numpy/
# http://www.lshift.net/blog/2009/10/29/python-quirks
# https://brennan.io/2016/03/02/logging-in-with-requests/
# https://talkpython.fm/episodes/show/86/python-at-stackoverflow
# http://sahandsaba.com/thirty-python-language-features-and-tricks-you-may-not-know.html
# http://ains.co/blog/things-which-arent-magic-flask-part-1.html
# http://ains.co/blog/things-which-arent-magic-flask-part-2.html
# http://blog.erezsh.com/how-to-write-a-calculator-in-50-python-lines-without-eval/
# https://www.youtube.com/watch?v=vs7XOn1TXVQ
# http://docs.python-guide.org/en/latest/
# http://maxburstein.com/blog/python-shortcuts-for-the-python-beginner/
# http://composingprograms.com/
# https://iluxonchik.github.io/why-you-should-learn-python/
# http://www.oreilly.com/programming/free/a-whirlwind-tour-of-python.csp
# http://programming-motherfucker.com/become.html#Python
# http://www.simplydjango.com/learn-python-efficiently/
# http://interactivepython.org/runestone/static/pythonds/index.html
# http://inventwithpython.com/bookshelf/
# http://pythonbooks.revolunet.com/
# http://openbookproject.net/thinkcs/python/english2e/
# http://williampross.com/7-must-read-python-books/
# https://www.loggly.com/blog/exceptional-logging-of-exceptions-in-python/
# https://nulab-inc.com/blog/nulab/advanced-method-define-tasks-fabric/
# http://stackoverflow.com/questions/231767/the-python-yield-keyword-explained
# http://prooffreaderplus.blogspot.ca/2014/11/top-10-python-idioms-i-wished-id.html
# https://github.com/amontalenti/elements-of-python-style
# https://pythonspot.com/en/python-debugging/
# https://sircmpwn.github.io/2017/01/13/The-problem-with-Python-3.html
# http://interactivepython.org/runestone/static/pythonds/index.html
# https://medium.com/p/40e9b2b36148
# https://pymotw.com/3/concurrent.futures/
# http://www.curiousvenn.com/?p=353
# http://www.datadependence.com/2016/05/scientific-python-pandas/
# https://cbrownley.wordpress.com/2016/06/26/parsing-pdfs-in-python-with-tika/
# https://www.paypal-engineering.com/2016/09/22/python-by-the-c-side/
# https://www.huyng.com/posts/python-performance-analysis
# https://ipgp.github.io/scientific_python_cheat_sheet/
# https://web.stanford.edu/~arbenson/cme193.html
# http://www.scipy-lectures.org/
# http://www.southampton.ac.uk/~fangohr/teaching/python/book.html
# http://jyotiska.github.io/blog/posts/getting_started_selenium.html
# http://nltk.org/book/ch03.html
# http://aaronsnitzer.com/writing/2016/04/27/virtualenv-and-pyvenv-beginner-tutorial.html
# http://dabapps.com/blog/introduction-to-pip-and-virtualenv-python/
# https://www.hackerschool.com/blog/14-there-is-no-magic-virtualenv-edition
# https://news.ycombinator.com/item?id=12285088
# https://ruslanspivak.com/lsbaws-part2/
# http://www.studytrails.com/blog/15-page-tutorial-for-r/
# http://pluto.huji.ac.il/~msby/StatThink/
# http://r-exercises.com/2016/07/22/start-here-to-learn-r/
# http://tryr.codeschool.com/
# http://swirlstats.com/students.html
# http://adv-r.had.co.nz/
# https://github.com/tdsmith/aRrgh
# http://alyssafrazee.com/introducing-R.html
# http://medianetwork.oracle.com/video/player/2623621262001
# http://www.theswarmlab.com/r-vs-python-round-1/
# http://cierareports.org/blog/2013/10/18/rCourse2013/index.html
# http://onepager.togaware.com/
# http://hackerretreat.com/r-good-parts/
# http://f.briatte.org/teaching/ida/index.html
# http://tim-smith.us/arrgh/index.html
# http://r4ds.had.co.nz/
# http://www.r-graph-gallery.com/all-graphs/
# http://blog.mailgun.com/machine-learning-for-everyday-tasks/
# http://www.pragtob.info/rails-beginner-cheatsheet/
# https://github.com/enaqx/awesome-react
# https://medium.com/@petehouston/install-and-config-redis-on-mac-os-x-via-homebrew-eb8df9a4f298#.xi91a8i33
# http://blog.fogus.me/2013/07/23/c-s-on-the-cheap/
# http://resrc.io/list/10/list-of-free-programming-books/
# http://blog.agupieware.com/2014/05/online-learning-bachelors-level.html
# https://github.com/vic317yeh/One-Click-to-Be-Pro
# http://queue.acm.org/detail.cfm?id=2949831
# http://hyperpolyglot.org/
# http://qntm.org/files/re/re.html
# http://regviz.org/
# http://www.thegeekstuff.com/2014/07/advanced-python-regex/
# http://www.vinta.com.br/blog/2016/5-tools-to-help-developing-and-testing-apis.html
# http://www.vinaysahni.com/best-practices-for-a-pragmatic-restful-api
# https://sheetsu.com/
# https://github.com/Microsoft/api-guidelines/blob/master/Guidelines.md
# http://apiworkbench.com/docs/
# https://github.com/qrohlf/sensible-web-development
# http://spenserj.com/blog/2013/07/15/securing-a-linux-server/
# https://news.ycombinator.com/item?id=5594739
# http://www.covert.io/security-datascience-papers/
# http://dfir.org/?q=node/8/
# http://blog.mailgun.com/security-guide-basic-infrastructure-security/
# https://paragonie.com/blog/2016/02/how-safely-store-password-in-2016
# https://news.ycombinator.com/item?id=11877575
# http://www.codelitt.com/blog/my-first-10-minutes-on-a-server-primer-for-securing-ubuntu/
# https://highon.coffee/blog/penetration-testing-tools-cheat-sheet/
# https://cybersecuritybase.github.io/
# http://www.pement.org/sed/sedfaq.html
# http://www.grymoire.com/Unix/sed.html
# http://docstore.mik.ua/orelly/unix/sedawk/appa_03.htm
# https://www.polemicdigital.com/2015/01/every-web-developer-know-seo/
# https://github.com/ripienaar/free-for-dev
# https://docs.python.org/2/howto/sockets.html
# https://www.nateberkopec.com/2015/09/30/action-cable.html
# http://treycausey.com/software_dev_skills.html
# http://chrismm.com/blog/project-delays-why-software-estimates/
# http://www.kalzumeus.com/2011/10/28/dont-call-yourself-a-programmer/
# http://semver.org/
# https://18f.gsa.gov/2015/11/17/choose-design-over-architecture/
# https://www.thumbtack.com/engineering/building-thumbtacks-data-infrastructure-part-ll/
# http://blog.yhat.com/posts/summarizing-data-in-SQL.html
# http://www.sohamkamani.com/blog/2016/07/07/a-beginners-guide-to-sql/
# http://www.sqlstyle.guide/
# https://blog.jooq.org/2016/04/25/10-sql-tricks-that-you-didnt-think-were-possible/
# http://revj.sourceforge.net/howto_run.html
# https://hackerlists.com/learn-sql-online/
# http://use-the-index-luke.com/sql/table-of-contents
# http://www.codinghorror.com/blog/2007/10/a-visual-explanation-of-sql-joins.html
# https://sivers.org/pg
# https://blog.0xbadc0de.be/archives/300
# https://karla.io/2016/04/30/ssh-for-fun-and-profit.html
# https://code.facebook.com/posts/365787980419535/scalable-and-secure-access-with-ssh/
# http://blog.tjll.net/ssh-kung-fu/
# http://heipei.github.io/2015/02/26/SSH-Agent-Forwarding-considered-harmful/
# http://blogs.perl.org/users/smylers/2011/08/ssh-productivity-tips.html
# https://www.clerky.com/yc-stock-plan-forms
# https://medium.com/@howietl/the-startup-legal-setup-guide-439b63bf68e8
# http://blog.professorbeekums.com/2016/11/hiring-software-developers-when-you-are.html
# http://swanintelligence.com/predicting-churn.html
# https://medium.com/@bryanedds/living-in-the-age-of-software-fuckery-8859f81ca877
# http://jacquesmattheij.com/ceo
# https://handbook.clerky.com/
# http://www.nicolabortignon.com/startup-reading-list/
# https://blog.ladder.io/business-idea/
# http://dlopuch.github.io/venture-dealr/
# https://codingvc.com/how-to-de-risk-a-startup/
# https://medium.com/@ehnertm/dont-get-attached-it-s-just-luck-26517994de30
# https://codingvc.com/how-to-use-thought-experiments-to-de-risk-your-startup/
# http://www.benkuhn.net/options
# https://www.oreilly.com/ideas/the-world-beyond-batch-streaming-101
# http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-5-Sympy.ipynb
# https://github.com/opsschool/curriculum
# https://github.com/chassing/linux-sysadmin-interview-questions
# https://ilya-sher.org/2016/05/19/tips-for-beginning-systems-and-software-engineers/
# http://bsdpunk.blogspot.ca/2013/09/facebook-first-level-interview-for.html
# http://sysadmincasts.com/
# https://naftuli.wtf/2017/01/12/systemd-is-awful/
# http://research.swtch.com/tcpviz
# http://jvns.ca/blog/2014/08/12/what-happens-if-you-write-a-tcp-stack-in-python/
# https://danielmiessler.com/study/tcpdump/
# http://robotframework.org/#introduction
# https://medium.com/@belisarius222/how-to-start-a-software-project-ad51373c1510
# https://ideqa.blogspot.ca/2016/10/key-points-to-software-testing.html
# http://www.bagtheweb.com/b/0qddaM
# https://blog.daknob.net/running-a-tor-exit-node-for-fun-and-e-mails/
# https://stateofdev.com/
# http://devo.ps/blog/2013/03/06/troubleshooting-5minutes-on-a-yet-unknown-box.html
# http://gafferongames.com/networking-for-game-programmers/udp-vs-tcp/
# https://github.com/tldr-pages/tldr
# http://cb.vu/unixtoolbox.xhtml
# http://bhami.com/rosetta.html
# http://www.noah.org/wiki/Dd_-_Destroyer_of_Disks
# http://spectrum.ieee.org/computing/software/the-strange-birth-and-long-life-of-unix/0
# http://blog.transmit.net/2008/10/my-best-unix-tricks.html
# https://www.linuxvoice.com/core-technology-signals/
# http://www.linusakesson.net/programming/tty/index.php
# https://github.com/mrzool/unix-as-ide
# https://www.nngroup.com/articles/computer-skill-levels/
# https://github.com/tpope/vim-sensible
# http://stackoverflow.com/questions/1218390/what-is-your-most-productive-shortcut-with-vim/1220118#1220118
# https://gist.github.com/gmccreight/7519289
# http://www.danielmiessler.com/study/vim/
# http://dougblack.io/words/a-good-vimrc.html
# https://github.com/mhinz/vim-galore
# http://lucapette.me/getting-started-with-vim
# https://dougblack.io/words/a-good-vimrc.html
# https://github.com/jlund/streisand
# https://uxdesign.cc/design-better-forms-96fadca0f49c
# https://www.nateberkopec.com/2015/10/07/frontend-performance-chrome-timeline.html
# https://medium.baqend.com/building-a-shop-with-sub-second-page-loads-lessons-learned-4bb1be3ed07
# https://changelog.com/essential-reading-list-for-getting-started-with-service-workers/
# https://ngrok.com/usage
# http://www.chrishardie.com/2013/05/end-of-website-development/
# https://github.com/kamranahmedse/developer-roadmap
# http://rodricios.github.io/posts/solving_the_data_extraction_problem.html
# http://sangaline.com/post/advanced-web-scraping-tutorial/
# https://code.google.com/p/browsersec/wiki/Part2#Same-origin_policy_for_cookies
# https://www.owasp.org/index.php/Cross-Site_Request_Forgery_%28CSRF%29_Prevention_Cheat_Sheet#Double_Submit_Cookies
# http://jgthms.com/web-design-in-4-minutes/
# http://www.nateberkopec.com/2015/10/21/hacking-head-tags-for-speed-and-profit.html
# http://blog.froont.com/brief-history-of-web-design-for-designers/
# http://www.smashingmagazine.com/2014/02/14/learning-resources-roundup/
# http://modernweb.com/2014/07/16/getting-started-modern-web-development/
# http://blog.trackduck.com/2014/07/21/10-web-development-design-blogs-need-bookmark/
# http://www.designer-daily.com/useful-free-tools-for-the-web-designers-toolbox-54665
# http://wwwhere.io/
# https://www.gitbook.com/book/frontendmasters/front-end-handbook/details
# http://www.freecodecamp.com/
# https://www.keycdn.com/blog/web-development-tools/
# https://viljamis.com/2016/typography-for-user-interfaces/
# https://internetingishard.com/html-and-css/
# https://zellwk.com/blog/typefaces/
# http://www.staticshin.com/programming/definitely-an-open-resty-guide/
# https://hsivonen.fi/producing-xml/
# http://www.dpawson.co.uk/xsl/sect2/nono.html
# http://jessenoller.com/blog/2009/04/13/yaml-aint-markup-language-completely-different
# https://github.com/crdoconnor/strictyaml/blob/master/FAQ.rst#why-should-i-use-strictyaml-instead-of-ordinary-YAML
# http://stackoverflow.com/a/21699210/127114

# %%
len(rest_of_source)
# Out:
# 3368

# %%
len(links_data)
# Out:
# 763

# %%
open('rest_of_source.txt','w').write('\n'.join(rest_of_source))
# Out:
# 121167

# %%
d
# Out:
# {'as': 'asa', 'bs': 'bsb'}

# %%
d.get('22as', '')
# Out:
# ''

# %%
"alksj3k3mM".lower()
# Out:
# 'alksj3k3mm'
